# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/sonu/work/aiml/_data/Dataset_USECASE2.csv',skiprows=1)
df = df.replace(np.nan, 0)
df.head()
# Out:
#                  StartDate                   EndDate  \
# 0  {"month":5,"year":2011}   {"month":4,"year":2013}
# 1  {"month":7,"year":2011}   {"month":7,"year":2016}
# 2  {"month":1,"year":2017}                         0
# 3  {"month":3,"year":2016}                         0
# 4  {"month":4,"year":2015}  {"month":12,"year":2015}
#
#                                          Description  \
# 0                                               none
# 1                                            Partner
# 2  Senior intelligence executive overseeing secur...
# 3                                               none
# 4                                               none
#
#                 StartDate.1                EndDate.1  \
# 0   {"month":1,"year":2018}                        0
# 1             {"year":2000}  {"month":7,"year":2011}
# 2   {"month":5,"year":2014}  {"month":3,"year":2015}
# 3  {"month":12,"year":2012}  {"month":8,"year":2013}
# ...

# %%
import re
from datetime import datetime

def parseIntoPyDate(input_text):
#   exp = "^{\"month\":(\d),\"year\":(\d+)}$"
    exp = "^{(\"month\":(\d),)?\"year\":(\d+)}$"
#     print(input_text)
    m   = re.match(exp, str(input_text))
    if m:
        matchlen = len(m.groups())
        month_match = m[matchlen-1]
        year_match = m[matchlen]
        if month_match is None:
            month_match = 1

        # Process the date
        date_str = "{month}/{day}/{year} {hour}:{min}:{sec}".format(month=month_match,day=1,year=year_match,hour=0,min=0,sec=0)
        date_fmt = datetime.strptime(date_str, '%m/%d/%Y %H:%M:%S')
        return date_fmt
    return input_text

# %%
str(parseIntoPyDate('{"year":2015}'))
# Out:
# '2015-01-01 00:00:00'

# %%
df2 = df.filter(regex=('StartDate.*|EndDate.*'))
columns = df2.columns.values.tolist()
df2.shape
# Out:
# (2998, 14)

# %%
df2["StartDate"] = df2["StartDate"].apply(lambda x: str(parseIntoPyDate(x)) if x!= None else x)
df2["StartDate"]
# for col in columns:
#     df2[col]
#     df2[col+"re"] = df2[col].apply(lambda x: re.match(exp,x))
# Out:
# /Users/sonu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       2011-05-01 00:00:00
# 1       2011-07-01 00:00:00
# 2       2017-01-01 00:00:00
# 3       2016-03-01 00:00:00
# 4       2015-04-01 00:00:00
#                ...
# 2993    2017-01-01 00:00:00
# 2994    2002-04-01 00:00:00
# 2995    2013-02-01 00:00:00
# 2996    2003-08-01 00:00:00
# 2997    2011-05-01 00:00:00
# Name: StartDate, Length: 2998, dtype: object

# %%
# prof_names=['startDate','EndDate','Description','UTCDate','UTCTime','col6','col7']

# def parse(UTCDate,UTCTime):
#     return dt.datetime.strptime(UTCDate, '%m/%d/%Y') + dt.timedelta(seconds=float(UTCTime))

# df = pd.read_csv(filename, delimiter=r'\s+', skiprows=25, index_col='date', parse_dates={'date':['UTCDate','UTCTime']}, names=names, date_parser=parse)
