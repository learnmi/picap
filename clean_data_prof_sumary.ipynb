# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/sonu/work/aiml/_data/Dataset_USECASE2.csv',skiprows=1)
df = df.replace(np.nan, 0)
# Out:
#                  StartDate                   EndDate  \
# 0  {"month":5,"year":2011}   {"month":4,"year":2013}
# 1  {"month":7,"year":2011}   {"month":7,"year":2016}
# 2  {"month":1,"year":2017}                         0
# 3  {"month":3,"year":2016}                         0
# 4  {"month":4,"year":2015}  {"month":12,"year":2015}
#
#                                          Description  \
# 0                                               none
# 1                                            Partner
# 2  Senior intelligence executive overseeing secur...
# 3                                               none
# 4                                               none
#
#                 StartDate.1                EndDate.1  \
# 0   {"month":1,"year":2018}                        0
# 1             {"year":2000}  {"month":7,"year":2011}
# 2   {"month":5,"year":2014}  {"month":3,"year":2015}
# 3  {"month":12,"year":2012}  {"month":8,"year":2013}
# 4   {"month":1,"year":2013}  {"month":3,"year":2015}
#
#                                        Description.1              StartDate.2  \
# 0                                               none  {"month":4,"year":2013}
# 1  Leads and Manages Global Technology (Horizonta...            {"year":2000}
# 2  Responsible for IBM's acquisition integration ...  {"month":9,"year":2000}
# 3                                         IS Auditor  {"month":9,"year":2007}
# 4                                               none            {"year":2008}
#
#                  EndDate.2                                      Description.2  \
# 0  {"month":1,"year":2018}                                               none
# 1  {"month":7,"year":2011}  BI and Analytics \nIT Strategy and Architectur...
# 2  {"month":8,"year":2002}  Senior Information Technology Executive respon...
# 3  {"month":4,"year":2009}                                               none
# 4  {"month":7,"year":2011}  Operations and HR Activities\nRecruitment\nCli...
#
#                StartDate.3  ...  \
# 0                        0  ...
# 1  {"month":3,"year":2018}  ...
# 2  {"month":1,"year":2003}  ...
# 3  {"month":4,"year":2009}  ...
# 4  {"month":1,"year":2016}  ...
#
#                                       Description.15 Type.5  \
# 0                                                  0      0
# 1  Ravi is an absolute go getter, he can energize...  given
# 2                                                  0      0
# 3                                                  0      0
# 4  Ashwini is the Best at her work.....she knows ...  given
#
#                                       Description.16 Type.6  \
# 0                                                  0      0
# 1  "I got to know Gautam, when I joined Cognizant...  given
# 2                                                  0      0
# 3                                                  0      0
# 4  An excellent example for Never Give up Attitud...  given
#
#                                       Description.17    Type.7  \
# 0                                                  0         0
# 1  Kumar is an outstanding Manager who continuous...     given
# 2                                                  0         0
# 3                                                  0         0
# 4  Pallavi... inshort Amul dabba! a sweet gal who...  received
#
#                                       Description.18 Type.8  \
# 0                                                  0      0
# 1  I have known Sunder for at least four years.  ...  given
# 2                                                  0      0
# 3                                                  0      0
# 4  She is extremely well organized in her approac...      0
#
#                                       Description.19 Unnamed: 47
# 0                                                  0         0.0
# 1  Sujith is one of the best Management Consultan...         0.0
# 2                                                  0         0.0
# 3                                                  0         0.0
# 4                                                  0         0.0
#
# [5 rows x 48 columns]

# %%
import re
from datetime import datetime

def parseIntoPyDate(input_text):
#   exp = "^{\"month\":(\d),\"year\":(\d+)}$"
    exp = "^{(\"month\":(\d+),)?\"year\":(\d+)}$"
#     print(input_text)
    m   = re.match(exp, str(input_text))
    if m:
        matchlen = len(m.groups())
        month_match = m[matchlen-1]
        year_match = m[matchlen]
        if month_match is None:
            month_match = 1
        # Process the date
        date_str = "{month}/{day}/{year} {hour}:{min}:{sec}".format(month=month_match,day=1,year=year_match,hour=0,min=0,sec=0)
        date_fmt = datetime.strptime(date_str, '%m/%d/%Y %H:%M:%S')
        return date_fmt
    return input_text

# %%
# str(parseIntoPyDate('{"month":10,"year":2016}'))

# %%
df2 = df.filter(regex=('StartDate.*|EndDate.*'))
columns = df2.columns.values.tolist()

# %%
# df2["mod."+ StartDate] = df2["StartDate"].apply(lambda x: str(parseIntoPyDate(x)) if x!= None else x)
# Format all columns
for col in columns:
    df2["mod." + col] =  df2[col].apply(lambda x: str(parseIntoPyDate(x)) if x!= None else x)
df2.head()
# Out:
# /Users/sonu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                  StartDate                   EndDate  \
# 0  {"month":5,"year":2011}   {"month":4,"year":2013}
# 1  {"month":7,"year":2011}   {"month":7,"year":2016}
# 2  {"month":1,"year":2017}                         0
# 3  {"month":3,"year":2016}                         0
# 4  {"month":4,"year":2015}  {"month":12,"year":2015}
#
#                 StartDate.1                EndDate.1              StartDate.2  \
# 0   {"month":1,"year":2018}                        0  {"month":4,"year":2013}
# 1             {"year":2000}  {"month":7,"year":2011}            {"year":2000}
# 2   {"month":5,"year":2014}  {"month":3,"year":2015}  {"month":9,"year":2000}
# 3  {"month":12,"year":2012}  {"month":8,"year":2013}  {"month":9,"year":2007}
# 4   {"month":1,"year":2013}  {"month":3,"year":2015}            {"year":2008}
#
#                  EndDate.2              StartDate.3                 EndDate.3  \
# 0  {"month":1,"year":2018}                        0                         0
# 1  {"month":7,"year":2011}  {"month":3,"year":2018}                         0
# 2  {"month":8,"year":2002}  {"month":1,"year":2003}   {"month":7,"year":2003}
# 3  {"month":4,"year":2009}  {"month":4,"year":2009}  {"month":11,"year":2012}
# 4  {"month":7,"year":2011}  {"month":1,"year":2016}                         0
#
#                 StartDate.4                 EndDate.4  ...  \
# 0                         0                         0  ...
# 1   {"month":3,"year":2000}   {"month":2,"year":2006}  ...
# 2   {"month":3,"year":2015}  {"month":12,"year":2016}  ...
# 3   {"month":2,"year":2005}   {"month":9,"year":2005}  ...
# 4  {"month":12,"year":2011}   {"month":3,"year":2013}  ...
#
#        mod.StartDate.2        mod.EndDate.2      mod.StartDate.3  \
# 0  2013-04-01 00:00:00  2018-01-01 00:00:00                    0
# 1  2000-01-01 00:00:00  2011-07-01 00:00:00  2018-03-01 00:00:00
# 2  2000-09-01 00:00:00  2002-08-01 00:00:00  2003-01-01 00:00:00
# 3  2007-09-01 00:00:00  2009-04-01 00:00:00  2009-04-01 00:00:00
# 4  2008-01-01 00:00:00  2011-07-01 00:00:00  2016-01-01 00:00:00
#
#          mod.EndDate.3      mod.StartDate.4        mod.EndDate.4  \
# 0                    0                    0                    0
# 1                    0  2000-03-01 00:00:00  2006-02-01 00:00:00
# 2  2003-07-01 00:00:00  2015-03-01 00:00:00  2016-12-01 00:00:00
# 3  2012-11-01 00:00:00  2005-02-01 00:00:00  2005-09-01 00:00:00
# 4                    0  2011-12-01 00:00:00  2013-03-01 00:00:00
#
#        mod.StartDate.5        mod.EndDate.5      mod.StartDate.6  \
# 0                    0                    0                    0
# 1  1994-01-01 00:00:00  2000-01-01 00:00:00  2016-06-01 00:00:00
# 2  2012-01-01 00:00:00  2014-05-01 00:00:00                    0
# 3  2006-02-01 00:00:00  2007-09-01 00:00:00  2013-08-01 00:00:00
# 4  2008-06-01 00:00:00  2011-12-01 00:00:00                    0
#
#          mod.EndDate.6
# 0                    0
# 1  2018-03-01 00:00:00
# 2                    0
# 3  2016-02-01 00:00:00
# 4                    0
#
# [5 rows x 28 columns]

# %%
# def findDuration(str_time1, str_time2):
def findDuration(x):
    str_time1 = x[0]
    str_time2 = x[1]
    # for data missing
    if str_time1 == '0' or str_time2 == '0':
        return 0
    time1 = datetime.strptime(str_time1, '%Y-%m-%d %H:%M:%S')
    time2 = datetime.strptime(str_time2, '%Y-%m-%d %H:%M:%S')    
    duration = time2 - time1
#     print("duration =>" + str(duration.days))
    return duration.days

# %%
# Process duration and add to main dataset
# Enumerate columns
df2.head()
columns = df2.columns.values.tolist()

# %%
for col in columns:
    if col.startswith('mod.StartDate'):
        splits = col.split('.')
        if len(splits) == 3:
            col_suffix = "." + splits[2]
        else:
            col_suffix = ""
        colname_duration = "Duration" + col_suffix
        print(colname_duration)
        # Update the original
        df[colname_duration] = df2[[col,"mod.EndDate"+ col_suffix]].apply(lambda x: findDuration(x), axis = 1)
    else:
        continue
# Out:
# Duration
# Duration.1
# Duration.2
# Duration.3
# Duration.4
# Duration.5
# Duration.6

# %%
df.head()
# Out:
#                  StartDate                   EndDate  \
# 0  {"month":5,"year":2011}   {"month":4,"year":2013}
# 1  {"month":7,"year":2011}   {"month":7,"year":2016}
# 2  {"month":1,"year":2017}                         0
# 3  {"month":3,"year":2016}                         0
# 4  {"month":4,"year":2015}  {"month":12,"year":2015}
#
#                                          Description  \
# 0                                               none
# 1                                            Partner
# 2  Senior intelligence executive overseeing secur...
# 3                                               none
# 4                                               none
#
#                 StartDate.1                EndDate.1  \
# 0   {"month":1,"year":2018}                        0
# 1             {"year":2000}  {"month":7,"year":2011}
# 2   {"month":5,"year":2014}  {"month":3,"year":2015}
# 3  {"month":12,"year":2012}  {"month":8,"year":2013}
# 4   {"month":1,"year":2013}  {"month":3,"year":2015}
#
#                                        Description.1              StartDate.2  \
# 0                                               none  {"month":4,"year":2013}
# 1  Leads and Manages Global Technology (Horizonta...            {"year":2000}
# 2  Responsible for IBM's acquisition integration ...  {"month":9,"year":2000}
# 3                                         IS Auditor  {"month":9,"year":2007}
# 4                                               none            {"year":2008}
#
#                  EndDate.2                                      Description.2  \
# 0  {"month":1,"year":2018}                                               none
# 1  {"month":7,"year":2011}  BI and Analytics \nIT Strategy and Architectur...
# 2  {"month":8,"year":2002}  Senior Information Technology Executive respon...
# 3  {"month":4,"year":2009}                                               none
# 4  {"month":7,"year":2011}  Operations and HR Activities\nRecruitment\nCli...
#
#                StartDate.3  ... Type.8  \
# 0                        0  ...      0
# 1  {"month":3,"year":2018}  ...  given
# 2  {"month":1,"year":2003}  ...      0
# 3  {"month":4,"year":2009}  ...      0
# 4  {"month":1,"year":2016}  ...      0
#
#                                       Description.19 Unnamed: 47 Duration  \
# 0                                                  0         0.0      701
# 1  Sujith is one of the best Management Consultan...         0.0     1827
# 2                                                  0         0.0        0
# 3                                                  0         0.0        0
# 4                                                  0         0.0      244
#
#   Duration.1 Duration.2 Duration.3 Duration.4 Duration.5 Duration.6
# 0          0       1736          0          0          0          0
# 1       4199       4199          0       2163       2191        638
# 2        304        699        181        641        851          0
# 3        243        578       1310        212        577        914
# 4        789       1277          0        456       1278          0
#
# [5 rows x 55 columns]
